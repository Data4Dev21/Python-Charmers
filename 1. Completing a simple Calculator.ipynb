# %%
# Exercise 1: Completing a Simple Calculator
# Objective: Finish a partially built calculator to understand variable assignments and basic arithmetic operations.

# Starting Code:
# Given values
number1 = 8
number2 = 4

# Sum - Complete the operation
sum_result = number1 + number2  # Replace None with the correct operation

# Product - Complete the operation
product_result = number1 * number2  # Replace None with the correct operation

# Print results (do not modify)
print(f"The sum of {number1} and {number2} is {sum_result}.") #dynamic
print(f"The product of {number1} and {number2} is {product_result}.")
print("The sum of 8 and 4 is", sum_result) #harcoded
print("The product of 8 and 4 is", product_result) #harcoded
# Out:
# The sum of 8 and 4 is 12.
# The product of 8 and 4 is 32.
# The sum of 8 and 4 is 12
# The product of 8 and 4 is 32

# %%
# Exercise 2: Favorite Foods List Manipulation
# Objective: Complete a script to manipulate a list of favorite foods and use string concatenation.

# Starting Code:
# Favorite foods list (do not modify)
favorite_foods = ["pizza", "sushi", "tacos", "pasta", "salad"]

# Print the entire list (Complete the code)
print("Favorite Foods:", favorite_foods) 

# Print the third item in the list (Complete the code)
print("Third Item:", favorite_foods[2]) 

# Favorite food sentence (Complete the code)
favorite_sentence = f"My favorite food is {favorite_foods[2]}." # Add the favorite food from the list
favorite_sentence2 = "My favorite food is "+ favorite_foods[2]+" ." # Add the favorite food from the list
print(favorite_sentence)
print(favorite_sentence2)
# Out:
# Favorite Foods: ['pizza', 'sushi', 'tacos', 'pasta', 'salad']
# Third Item: tacos
# My favorite food is tacos.
# My favorite food is tacos .

# %%
# Exercise 3: Simple aggreations
# Objective: Complete the analysis of a dataset to find average, maximum, and minimum values.

# Starting Code:
# Given dataset (do not modify)
data = [23, 17, 34, 29, 12, 38, 45, 24]

# Average calculation (Complete the code)
average = sum(data)/len(data)  # Replace None with the calculation

# Average calculation (Complete the code) using a loop
total=0
for num in data:
    total=total+num
average2 = total/len(data)  # Replace None with the calculation 

#or
# Average calculation (Complete the code) using a loop
total=0
for num in data:
    total+=num
average3 = total/len(data)  # Replace None with the calculation 

# Average calculation (Complete the code) using a statistics library
import statistics
average4 = statistics.mean(data)  # Replace None with the calculation 

# Find max and min (Complete the code)
max_value = max(data)  # Replace None with the calculation

#or   # Replace None with the calculation using loop
max_value2 = (data[0])

for num in data:
 if num>max_value2:
     max_value2=num

min_value = min(data)  # Replace None with the calculation

#or   # Replace None with the calculation using loop
min_value2 = (data[0])

for num in data:
 if num<min_value2:
     min_value2=num



# Print results (do not modify)
print(f"Average: {average}")
print(f"Average2: {average2}")
print(f"Average3: {average3}")
print(f"Average4: {average4}")
print(f"Maximum: {max_value}")
print(f"Maximum2: {max_value2}")
print(f"Minimum: {min_value}")
print(f"Minimum2: {min_value2}")
# Out:
# Average: 27.75
# Average2: 27.75
# Average3: 27.75
# Average4: 27.75
# Maximum: 45
# Maximum2: 45
# Minimum: 12
# Minimum2: 12
