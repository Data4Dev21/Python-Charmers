# %%
#Data frames are made up of 1 or more series
#Name of the series are the column names
#Index are the row numbers

# %%
import pandas as pd

meteorites = pd.read_csv('../data/Meteorite_Landings.csv',nrows=3)
meteorites
# Out:
#      name  id nametype recclass  mass (g)  fall                    year  \
# 0  Aachen   1    Valid       L5        21  Fell  01/01/1880 12:00:00 AM
# 1  Aarhus   2    Valid       H6       720  Fell  01/01/1951 12:00:00 AM
# 2    Abee   6    Valid      EH4    107000  Fell  01/01/1952 12:00:00 AM
#
#      reclat    reclong           GeoLocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# 1  56.18333   10.23333  (56.18333, 10.23333)
# 2  54.21667 -113.00000    (54.21667, -113.0)

# %%
import pandas as pd

meteorites = pd.read_csv('../data/Meteorite_Landings.csv',nrows=3)
meteorites.head()
# Out:
#      name  id nametype recclass  mass (g)  fall                    year  \
# 0  Aachen   1    Valid       L5        21  Fell  01/01/1880 12:00:00 AM
# 1  Aarhus   2    Valid       H6       720  Fell  01/01/1951 12:00:00 AM
# 2    Abee   6    Valid      EH4    107000  Fell  01/01/1952 12:00:00 AM
#
#      reclat    reclong           GeoLocation
# 0  50.77500    6.08333     (50.775, 6.08333)
# 1  56.18333   10.23333  (56.18333, 10.23333)
# 2  54.21667 -113.00000    (54.21667, -113.0)

# %%
#Series
meteorites.name
# Out:
# 0    Aachen
# 1    Aarhus
# 2      Abee
# Name: name, dtype: object

# %%
#Columns
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
#Creating Data Frames
#Can be done from sources such as other 
#Python objects
#flat files
#webscraping
#and API requests.

# %%
#Flat File

import pandas as pd

meteorites = pd.read_csv('../data/Meteorite_Landings.csv')

# %%
#API
import requests

response = requests.get(
    'https://data.nasa.gov/resource/gh4g-9sfh.json',
    params={'$limit': 50_000}
)

if response.ok:
    payload = response.json()
else:
    print(f'Request was not successful and returned code: {response.status_code}.')
    payload = None

# %%
import pandas as pd

df = pd.DataFrame(payload)
df.head(3)

# %%
#DataFrame Inspection

#Rows and Colummn
meteorites.shape
# Out:
# (45716, 10)

# %%
#Colummns

meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
#DatTypes

meteorites.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
#General Info
meteorites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
#upper view

meteorites.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
#bottom view

meteorites.tail()
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 45711  01/01/1990 12:00:00 AM  29.03700   17.01850       (29.037, 17.0185)
# 45712  01/01/1999 12:00:00 AM  13.78333    8.96667     (13.78333, 8.96667)
# 45713  01/01/1939 12:00:00 AM  49.25000   17.66667       (49.25, 17.66667)
# 45714  01/01/2003 12:00:00 AM  49.78917   41.50460     (49.78917, 41.5046)
# 45715  01/01/1976 12:00:00 AM  33.98333 -115.68333  (33.98333, -115.68333)

# %% [markdown]
# Exercise 1
# Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
# import package_name
import pandas as pd

# read file to variable
df = pd.read_csv('../data/2019_Yellow_Taxi_Trip_Data.csv')

# print the first 5 rows
df.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %% [markdown]
# Exercise 2
# Find the dimensions (number of rows and number of columns) in the data.

# %%
df.shape
# Out:
# (10000, 18)

# %% [markdown]
# Extracting subsets¶
# A crucial part of working with DataFrames is extracting subsets of the data: finding rows that meet a certain set of criteria, isolating columns/rows of interest, etc.
# After narrowing down our data, we are closer to discovering insights. This section will be the backbone of many analysis tasks.

# %%
#Selecting a column
df.vendorid
# Out:
# 0       2
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: vendorid, Length: 10000, dtype: int64

# %%
#Multiple columns
df[['vendorid','extra']]
# Out:
#       vendorid  extra
# 0            2    1.0
# 1            1    1.0
# 2            2    1.0
# 3            2    1.0
# 4            2    1.0
# ...        ...    ...
# 9995         1    3.5
# 9996         1    3.5
# 9997         1    1.0
# 9998         1    1.0
# 9999         1    3.5
#
# [10000 rows x 2 columns]

# %%
#Selecting Rows
df[10:20]
# Out:
#     vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 10         1  2019-10-23T16:35:02.000  2019-10-23T17:57:38.000
# 11         1  2019-10-23T16:17:33.000  2019-10-23T16:32:58.000
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: fare_amount, Length: 10000, dtype: bool

# %% [markdown]
# Calculating Summary Statistics

# %%
#Finding the counts

df.store_and_fwd_flag.value_counts()
# Out:
# store_and_fwd_flag
# N    9838
# Y     162
# Name: count, dtype: int64

# %% [markdown]
# What was the average trip distance?

# %%
df['trip_distance'].mean()
# Out:
# np.float64(3.01525)

# %% [markdown]
# Quantile

# %%
df['trip_distance'].quantile([0.01, 0.05, 0.5, 0.95, 0.99])
# Out:
# 0.01     0.0000
# 0.05     0.4300
# 0.50     1.5000
# 0.95    13.7225
# 0.99    19.3000
# Name: trip_distance, dtype: float64

# %% [markdown]
# Median

# %%
df['trip_distance'].median()
# Out:
# np.float64(1.5)

# %% [markdown]
# Longest Journey

# %%
df['trip_distance'].max()
# Out:
# np.float64(38.11)

# %% [markdown]
# Further info on the Longest Journey

# %%
df.loc[df['trip_distance'].idxmax()]
# Out:
# vendorid                                       2
# tpep_pickup_datetime     2019-10-23T16:50:53.000
# tpep_dropoff_datetime    2019-10-24T15:32:55.000
# passenger_count                                1
# trip_distance                              38.11
# ratecodeid                                     5
# store_and_fwd_flag                             N
# pulocationid                                 132
# dolocationid                                 265
# payment_type                                   1
# fare_amount                                176.0
# extra                                        0.0
# mta_tax                                      0.5
# tip_amount                                 18.29
# tolls_amount                                6.12
# improvement_surcharge                        0.3
# total_amount                              201.21
# congestion_surcharge                         0.0
# Name: 8338, dtype: object

# %% [markdown]
# Summary Statistics

# %%
df.describe(include=[float])
# Out:
#        trip_distance   fare_amount         extra       mta_tax    tip_amount  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        3.015250     15.106313      1.960235      0.492450      2.634494
# std         4.148063     13.954762      1.392940      0.071544      3.409800
# min         0.000000    -52.000000     -4.500000     -0.500000      0.000000
# 25%         0.920000      7.000000      1.000000      0.500000      0.000000
# 50%         1.500000     10.000000      1.000000      0.500000      2.000000
# 75%         2.760000     16.000000      3.500000      0.500000      3.250000
# max        38.110000    176.000000      7.000000      0.500000     43.000000
#
#        tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# count  10000.000000           10000.000000  10000.000000          10000.000000
# mean       0.623447               0.298140     22.564659              2.282800
# ...

# %%
#for specific columns

df[['fare_amount', 'tip_amount', 'tolls_amount','total_amount']].describe()
# Out:
#         fare_amount    tip_amount  tolls_amount  total_amount
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      15.106313      2.634494      0.623447     22.564659
# std       13.954762      3.409800      6.437507     19.209255
# min      -52.000000      0.000000     -6.120000    -65.920000
# 25%        7.000000      0.000000      0.000000     12.375000
# 50%       10.000000      2.000000      0.000000     16.300000
# 75%       16.000000      3.250000      0.000000     22.880000
# max      176.000000     43.000000    612.000000    671.800000

# %% [markdown]
# Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
#Logest distance

# Find the index of the oldest person
index_longest = df['trip_distance'].idxmax()

# Get height, weight, and salary directly
result = df.loc[index_longest, ['fare_amount', 'tip_amount', 'total_amount', 'tolls_amount']]
print(result)
# Out:
# fare_amount      176.0
# tip_amount       18.29
# total_amount    201.21
# tolls_amount      6.12
# Name: 8338, dtype: object
